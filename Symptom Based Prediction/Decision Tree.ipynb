# %%
import pandas as pds
import numpy as nmp
import seaborn as sbs
import matplotlib.pyplot as plt
# %matplotlib inline
import math

ds=pds.read_csv("Covid Dataset.csv")
sbs.countplot(x="COVID-19",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Breathing Problem",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Fever",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Dry Cough",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Sore throat",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Running Nose",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Asthma",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Chronic Lung Disease",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Headache",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Heart Disease",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Diabetes",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Contact with COVID Patient",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Fatigue ",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Gastrointestinal ",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Abroad travel",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Hyper Tension",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Wearing Masks",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
sbs.countplot(x="COVID-19",hue="Sanitization from Market",data=ds)
# Out:
# <AxesSubplot:xlabel='COVID-19', ylabel='count'>

# %%
ds=ds.replace(["Yes","No"],[1,0])

# %%
ds=ds.drop(['Running Nose','Asthma','Headache','Heart Disease','Diabetes','Hyper Tension','Fatigue ','Gastrointestinal ','Wearing Masks','Sanitization from Market','Chronic Lung Disease'],axis=1)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5434 entries, 0 to 5433
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Breathing Problem                        5434 non-null   int64
#  1   Fever                                    5434 non-null   int64
#  2   Dry Cough                                5434 non-null   int64
#  3   Sore throat                              5434 non-null   int64
#  4   Abroad travel                            5434 non-null   int64
#  5   Contact with COVID Patient               5434 non-null   int64
#  6   Attended Large Gathering                 5434 non-null   int64
#  7   Visited Public Exposed Places            5434 non-null   int64
#  8   Family working in Public Exposed Places  5434 non-null   int64
#  9   COVID-19                                 5434 non-null   int64
# dtypes: int64(10)
# memory usage: 424.7 KB

# %%
ds.corr()
# Out:
#                                          Breathing Problem     Fever  \
# Breathing Problem                                 1.000000  0.089903
# Fever                                             0.089903  1.000000
# Dry Cough                                         0.159562  0.127580
# Sore throat                                       0.303768  0.322235
# Abroad travel                                     0.117795  0.128726
# Contact with COVID Patient                        0.214634  0.164704
# Attended Large Gathering                          0.200304  0.070490
# Visited Public Exposed Places                     0.066688  0.002252
# Family working in Public Exposed Places           0.018295  0.012102
# COVID-19                                          0.443764  0.352891
#
#                                          Dry Cough  Sore throat  \
# Breathing Problem                         0.159562     0.303768
# Fever                                     0.127580     0.322235
# ...

# %%
Y=ds["COVID-19"]
X=ds.drop(["COVID-19"],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_tr,X_te,Y_tr,Y_te=train_test_split(X,Y,test_size=0.2,random_state=42)  #change in random state 
from sklearn import tree
t = tree.DecisionTreeClassifier( criterion="gini",max_depth=10)
                               
t.fit(X_tr,Y_tr)
Y_pred = t.predict(X_te)

acc_decisiontree=t.score(X_te, Y_te)*100
acc_decisiontrain=t.score(X_tr, Y_tr)*100
print("TRAIN:",acc_decisiontrain)
print("TEST:",acc_decisiontree)
# Out:
# TRAIN: 97.17046238785369
# TEST: 97.60809567617295

# %%
    from sklearn import decomposition, datasets
    from sklearn import tree
    from sklearn.pipeline import Pipeline
    from sklearn.model_selection import GridSearchCV
    from sklearn.preprocessing import StandardScaler
    Y=ds["COVID-19"]
    X=ds.drop(["COVID-19"],axis=1)
    # Creating an standardscaler object
    strdslc= StandardScaler()

    # Creating a pca object
    pca = decomposition.PCA()

    # Creating a DecisionTreeClassifier
    t = tree.DecisionTreeClassifier()

    # Creating a pipeline of three steps. First, standardizing the data.
    # Second, tranforming the data with PCA.
    # Third, training a Decision Tree Classifier on the data.
    pipe = Pipeline(steps=[('std_slc', strdslc),
                           ('pca', pca),
                           ('dec_tree',t)])

    # Creating Parameter Space
    # Creating a list of a sequence of integers from 1 to 30 (the number of features in X + 1)
    n_components = list(range(1,X.shape[1]+1,1))

    # Creating lists of parameter for Decision Tree Classifier
    criterion = ['gini', 'entropy']
    max_depth = [10,12,20,24]

    # Creating a dictionary of all the parameter options 
    # Note that we can access the parameters of steps of a pipeline by using '__’
    parameters = dict(pca__n_components=n_components,
                      dec_tree__criterion=criterion,
                      dec_tree__max_depth=max_depth)

    # Conducting Parameter Optmization With Pipeline
    # Creating a grid search object
    clf_GS = GridSearchCV(pipe, parameters)

    # Fitting the grid search
    clf_GS.fit(X, Y)

    # Viewing The Best Parameters
    print('Best Criterion:', clf_GS.best_estimator_.get_params()['dec_tree__criterion'])
    print('Best max_depth:', clf_GS.best_estimator_.get_params()['dec_tree__max_depth'])
    print('Best Number Of Components:', clf_GS.best_estimator_.get_params()['pca__n_components'])
# Out:
# Best Criterion: entropy
# Best max_depth: 12
# Best Number Of Components: 4

# %%
#OUTPUT FOR THE SPECIFIED INPUT:
BreathingProblem=1
Fever=1
DryCough=1
Sorethroat=0
Abroadtravel=0
Contact_with_COVID_Patient=0
Attended_Large_Gathering=0
Visited_Public_Exposed_Places=0
Family_working_in_Public_Exposed_Places=0
myinput = [[BreathingProblem,Fever,DryCough,Sorethroat,Abroadtravel,Contact_with_COVID_Patient,Attended_Large_Gathering,Visited_Public_Exposed_Places,Family_working_in_Public_Exposed_Places]]
t.fit(X_tr,Y_tr)
myoutput = t.predict(myinput)
print("0 stands for 'NO' and 1 stands for 'YES'")
print("GIVEN INPUTS:")
print("BreathingProblem:",BreathingProblem)
print("Fever:",Fever)
print("DryCough:",DryCough)
print("Sorethroat:",Sorethroat)
print("Abroadtravel:",Abroadtravel)
print("Contact_with_COVID_Patient:",Contact_with_COVID_Patient)
print("Attended_Large_Gathering:",Attended_Large_Gathering)
print("Visited_Public_Exposed_Places:",Visited_Public_Exposed_Places)
print("Family_working_in_Public_Exposed_Places:",Family_working_in_Public_Exposed_Places)
print("\n")
print("OUTPUT:")
if(myoutput==1):
    print("The Person is said to have higher chances of having COVID")
else:
    print("The Person doesn't have COVID")
# Out:
# 0 stands for 'NO' and 1 stands for 'YES'
# GIVEN INPUTS:
# BreathingProblem: 1
# Fever: 1
# DryCough: 1
# Sorethroat: 0
# Abroadtravel: 0
# Contact_with_COVID_Patient: 0
# Attended_Large_Gathering: 0
# Visited_Public_Exposed_Places: 0
# Family_working_in_Public_Exposed_Places: 0
#
#
# OUTPUT:
# The Person doesn't have COVID
